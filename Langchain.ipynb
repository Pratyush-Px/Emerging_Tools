# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratyush-Px/Emerging_Tools/blob/main/Langchain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain langchain-community langchain-google-genai chromadb langchainhub

# %%
from google.colab import userdata
import os
os.environ['GEMINI_API_KEY'] = userdata.get('geminiAPIkey')

# %%
#web scraping
from langchain_community.document_loaders import WebBaseLoader
loader = WebBaseLoader(web_paths = ["https://en.wikipedia.org/wiki/List_of_films_considered_the_best"])
docs = loader.load()
print(docs)

# %%
#splitting docs
